# %%
# !pip install -U accelerate &> /dev/null
# !pip install -U transformers &> /dev/null
# !pip install datasets &> /dev/null

# %% [markdown]
# # Fine-tuning RoBERTa for Text Classification on the sub dataset with stop words

# %%
import pandas as pd

df = pd.read_csv('dataset_v2.csv')

df.head()
# Out:
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/college-a...
# 1  https://www.huffingtonpost.com/entry/jcpenney-...
# 2  https://www.huffingtonpost.com/entry/why-stare...
# 3  https://www.huffingtonpost.com/entry/the-next-...
# 4  https://www.huffingtonpost.com/entry/disneys-p...
#
#                                             headline        category  \
# 0   There's No Rejecting the College Admissions Game       PARENTING
# 1  JCPenney Jewelry Bar In The Works: Bijoux Bar ...  STYLE & BEAUTY
# 2  Why Stare at the Floor in an Elevator When You...          TRAVEL
# 3    The Next Transformation in American Health Care        WELLNESS
# 4  Where To Blow Off Steam In Walt Disney World (...          TRAVEL
#
#                                    short_description  \
# 0  t easy application float cyberspace rejection ...
# 1  want sure check HuffPost Style Twitter Faceboo...
# 2  career consultant fond suggest careful people ...
# 3  crisis american healthcare today ascendance ch...
# 4  people think Disney vacation non stop action s...
#
#                                              authors        date
# 0  Linda Flanagan, Contributor\nFreelance writer ...  2013-03-28
# 1                                                NaN  2013-04-02
# 2  Maureen Anderson, Contributor\nMaureen Anderso...  2012-07-17
# 3  Brian Castrucci, Contributor\nChief Program an...  2014-03-06
# 4                                                NaN  2013-02-24

# %%
df.isna().sum()
# Out:
# link                    0
# headline                0
# category                0
# short_description      49
# authors              3414
# date                    0
# dtype: int64

# %%
df.dropna(subset=['short_description'], inplace=True)

# %%
df.isna().sum()
# Out:
# link                    0
# headline                0
# category                0
# short_description       0
# authors              3410
# date                    0
# dtype: int64

# %%
df.shape
# Out:
# (18932, 6)

# %%
unique_categories = df.category.unique()
category_to_idx = {category: idx for idx, category in enumerate(unique_categories)}
df['category_id'] = df.category.map(lambda category: category_to_idx[category])

df.head()
# Out:
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/college-a...
# 1  https://www.huffingtonpost.com/entry/jcpenney-...
# 2  https://www.huffingtonpost.com/entry/why-stare...
# 3  https://www.huffingtonpost.com/entry/the-next-...
# 4  https://www.huffingtonpost.com/entry/disneys-p...
#
#                                             headline        category  \
# 0   There's No Rejecting the College Admissions Game       PARENTING
# 1  JCPenney Jewelry Bar In The Works: Bijoux Bar ...  STYLE & BEAUTY
# 2  Why Stare at the Floor in an Elevator When You...          TRAVEL
# 3    The Next Transformation in American Health Care        WELLNESS
# 4  Where To Blow Off Steam In Walt Disney World (...          TRAVEL
#
#                                    short_description  \
# 0  t easy application float cyberspace rejection ...
# 1  want sure check HuffPost Style Twitter Faceboo...
# 2  career consultant fond suggest careful people ...
# 3  crisis american healthcare today ascendance ch...
# 4  people think Disney vacation non stop action s...
#
#                                              authors        date  category_id
# 0  Linda Flanagan, Contributor\nFreelance writer ...  2013-03-28            0
# 1                                                NaN  2013-04-02            1
# 2  Maureen Anderson, Contributor\nMaureen Anderso...  2012-07-17            2
# 3  Brian Castrucci, Contributor\nChief Program an...  2014-03-06            3
# 4                                                NaN  2013-02-24            2

# %%
from transformers import AutoTokenizer

model_ckpt = 'roberta-base'
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
def get_num_tokens(text: str) -> int:
    return len(tokenizer(text)['input_ids'])

df['Tokens Per Description'] = df.short_description.map(get_num_tokens)

df.head()
# Out:
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/college-a...
# 1  https://www.huffingtonpost.com/entry/jcpenney-...
# 2  https://www.huffingtonpost.com/entry/why-stare...
# 3  https://www.huffingtonpost.com/entry/the-next-...
# 4  https://www.huffingtonpost.com/entry/disneys-p...
#
#                                             headline        category  \
# 0   There's No Rejecting the College Admissions Game       PARENTING
# 1  JCPenney Jewelry Bar In The Works: Bijoux Bar ...  STYLE & BEAUTY
# 2  Why Stare at the Floor in an Elevator When You...          TRAVEL
# 3    The Next Transformation in American Health Care        WELLNESS
# 4  Where To Blow Off Steam In Walt Disney World (...          TRAVEL
#
#                                    short_description  \
# 0  t easy application float cyberspace rejection ...
# 1  want sure check HuffPost Style Twitter Faceboo...
# 2  career consultant fond suggest careful people ...
# 3  crisis american healthcare today ascendance ch...
# 4  people think Disney vacation non stop action s...
#
#                                              authors        date  category_id  \
# 0  Linda Flanagan, Contributor\nFreelance writer ...  2013-03-28            0
# 1                                                NaN  2013-04-02            1
# 2  Maureen Anderson, Contributor\nMaureen Anderso...  2012-07-17            2
# 3  Brian Castrucci, Contributor\nChief Program an...  2014-03-06            3
# 4                                                NaN  2013-02-24            2
#
#    Tokens Per Description
# 0                      20
# 1                      18
# 2                      12
# 3                      28
# 4                      14

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
df.boxplot('Tokens Per Description', by='category', grid=False, showfliers=False)
plt.suptitle('')
plt.xlabel('')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df, x='category', y='Tokens Per Description')

plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=90)
plt.show()

# %%
from datasets import Dataset, DatasetDict
from sklearn.model_selection import train_test_split

X = df.drop(columns=['category_id'])
y = df.category_id
X_train, X_temp, y_train, y_temp = train_test_split(X, y, train_size=0.8, stratify=y, random_state=42)
X_test, X_valid, y_test, y_valid = train_test_split(X_temp, y_temp, test_size=0.5, stratify=y_temp, random_state=42)

len(X_train), len(X_test), len(X_valid)
# Out:
# (15145, 1893, 1894)

# %%
train_dataset = Dataset.from_dict({'description': X_train.short_description.values.tolist(),
                                   'category': y_train.tolist()})
test_dataset = Dataset.from_dict({'description': X_test.short_description.values.tolist(),
                                  'category': y_test.tolist()})
validation_dataset = Dataset.from_dict({'description': X_valid.short_description.values.tolist(),
                                         'category': y_valid.tolist()})

dataset = DatasetDict({'train': train_dataset, 'test': test_dataset, 'validation': validation_dataset})

dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['description', 'category'],
#         num_rows: 15145
#     })
#     test: Dataset({
#         features: ['description', 'category'],
#         num_rows: 1893
#     })
#     validation: Dataset({
#         features: ['description', 'category'],
#         num_rows: 1894
#     })
# })

# %%
def tokenize(batch):
    return tokenizer(batch['description'], padding=True, truncation=True, add_special_tokens=True)

dataset_encoded = dataset.map(tokenize, batched=True, batch_size=None)
# Out:
# Map:   0%|          | 0/15145 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1893 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1894 [00:00<?, ? examples/s]

# %%
import torch
from transformers import AutoModel

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = AutoModel.from_pretrained(model_ckpt).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
dataset_encoded.set_format('torch', columns=['input_ids', 'attention_mask', 'category'])

# %%
len(df.category.unique())
# Out:
# 42

# %%
from transformers import AutoModelForSequenceClassification

num_labels = 42
model = (AutoModelForSequenceClassification
         .from_pretrained(model_ckpt, num_labels=num_labels)
         .to(device))
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from sklearn.metrics import accuracy_score, f1_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    f1 = f1_score(labels, preds, average="weighted")
    acc = accuracy_score(labels, preds)

    return {"accuracy": acc, "f1": f1}

# %%
dataset_encoded['train'] = dataset_encoded['train'].rename_column("category", "label")
dataset_encoded['test'] = dataset_encoded['test'].rename_column("category", "label")
dataset_encoded['validation'] = dataset_encoded['validation'].rename_column("category", "label")

# %%
from transformers import Trainer, TrainingArguments

batch_size = 64
logging_steps = len(dataset_encoded["train"]) // batch_size
model_name = f"{model_ckpt}-finetuned-news-v2"
training_args = TrainingArguments(output_dir=model_name,
                                  overwrite_output_dir='True',
                                  num_train_epochs=5,
                                  learning_rate=3e-5,
                                  per_device_train_batch_size=batch_size,
                                  per_device_eval_batch_size=batch_size,
                                  weight_decay=0.01,
                                  eval_strategy='epoch',
                                  disable_tqdm=False,
                                  logging_steps=logging_steps,
                                  push_to_hub=False,
                                  log_level="error",
                                  load_best_model_at_end=True,
                                  save_strategy='epoch',
                                  save_total_limit=1,
                                  seed=42,
                                  metric_for_best_model='accuracy')

# %%
from transformers import Trainer

trainer = Trainer(model=model, args=training_args,
                  compute_metrics=compute_metrics,
                  train_dataset=dataset_encoded["train"],
                  eval_dataset=dataset_encoded["test"],
                  tokenizer=tokenizer)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='1185' max='1185' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1185/1185 10:33, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.642600</td>
#       <td>2.182376</td>
#       <td>0.452192</td>
#       <td>0.381773</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.031500</td>
#       <td>2.018603</td>
#       <td>0.487586</td>
#       <td>0.435206</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.793400</td>
#       <td>1.966396</td>
#       <td>0.483888</td>
#       <td>0.442105</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.629000</td>
#       <td>1.931961</td>
#       <td>0.499208</td>
#       <td>0.457727</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.520900</td>
#       <td>1.927302</td>
#       <td>0.509773</td>
#       <td>0.472734</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1185, training_loss=1.9210546565961235, metrics={'train_runtime': 635.5071, 'train_samples_per_second': 119.157, 'train_steps_per_second': 1.865, 'total_flos': 4009604978164500.0, 'train_loss': 1.9210546565961235, 'epoch': 5.0})

# %%
eval = pd.DataFrame(trainer.evaluate(), index=['']).T

eval
# Out:
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 00:06]
#     </div>
#
# eval_loss                  1.927302
# eval_accuracy              0.509773
# eval_f1                    0.472734
# eval_runtime               6.566500
# eval_samples_per_second  288.279000
# eval_steps_per_second      4.569000
# epoch                      5.000000

# %%
preds = trainer.predict(dataset_encoded['validation'])

compute_metrics(preds)
# Out:
# {'accuracy': 0.5174234424498416, 'f1': 0.4784088306836251}

# %% [markdown]
# Results were pretty good. Let's see fine-tuning results for the sub dataset without stop words.
